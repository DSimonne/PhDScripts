# %% [markdown]
# # Look at rga data

# %%
# %%bash
# ls
# Out:
# 20210112-151135.txt
# 20210114_test.txt
# DataAnalysis.ipynb
# __pycache__
# RGAsrs.py
# utilities3.py
# xcat04.py

# %%
# %run -i RGAsrs.py

# %%
# %run -i xcat04.py

# %%
data, sttime, dictGas = RgaLoad("20210114_test.txt")

# %%
log_data = DataSet(".", "20210112-151135.txt")

# %%
NormRga = RgaNormPtotPlot("20210114_test.txt", [28, 32, 40, 44], 0.5, TimeRange = [sttime, 4500], plot = "YES")
