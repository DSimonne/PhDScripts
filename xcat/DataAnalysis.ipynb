# %% [markdown]
# # xcat.log entries
#
#
# ## 14/01
#
# Thu, 14 Jan 2021 15:12:56
# * do.run("Macro_LowCO.txt")
# * no log file
# * no data
#
#
# Thu, 14 Jan 2021 15:23:58
# * do.run("Macro_LowCO.txt")
# * no log file
# * **data: 20210114_test.txt**
#
#
# Thu, 14 Jan 2021 16:34:31
# * do.run("Macro_LowCO.txt")
# * no log file
# * no data
#
# ## 15/01
#
# Fri, 15 Jan 2021 10:57:30
# * do.run("Macro_LowCO.txt")
# * log: log_Macro_LowCO.txt_20210115_10h57.txt
# * 2021-01-15 10:57:30,933  --> /nfs/ruche-sixs/sixs-soleil/com-sixs/2021/Shutdown0/test/Macro_LowCO.txt ---
# * 2021-01-15 11:54:59,637  --> END (Macro_LowCO.txt)
# * **data: Test01.txt**
#
# Fri, 15 Jan 2021 12:08:17
# * do.run("MacroBatch.txt")
# * log: log_MacroBatch.txt_20210115_12h08.txt
# * 2021-01-15 12:08:17,836  --> /nfs/ruche-sixs/sixs-soleil/com-sixs/2021/Shutdown0/test/MacroBatch.txt ---
# * 2021-01-15 13:21:55,942  --> END (MacroBatch.txt)
# * 2021-01-15 13:29:44,811  --> END (MacroCOStochio.txt)
# * **data : Testbatchfinal.txt**
#
# Fri, 15 Jan 2021 13:29:44
# * do.run("MacroCOStochio.txt")
# * no log file
# * no data
#
# Fri, 15 Jan 2021 13:32:17
# * do.run("MacroCOStochio.txt")
# * no log file
# * no data
#
# Fri, 15 Jan 2021 13:34:54
# * do2.run("MacroCOStochio.txt")
# * no log file
# * no data
#
# Fri, 15 Jan 2021 13:35:04
# * do.run("MacroBatch.txt")
# * no log file
# * no data
#
# Fri, 15 Jan 2021 13:35:46
# * do2.run("MacroCOStochio.txt")
# * log: log_MacroBatch.txt_20210115_13h35.txt
# * 2021-01-15 13:35:04,524  --> /nfs/ruche-sixs/sixs-soleil/com-sixs/2021/Shutdown0/test/MacroBatch.txt ---
# * 2021-01-15 13:35:07,467  --> END (MacroBatch.txt)
# * 2021-01-15 13:35:56,549  --> END (MacroCOStochio.txt)
# * no data
#
# Fri, 15 Jan 2021 13:35:56
# * do.run("MacroCOStochio.txt")
# * no log file
# * no data
#
# Fri, 15 Jan 2021 13:37:42
# * do.run("MacroCOStochio.txt")
# * log: log_MacroCOStochio.txt_20210115_13h37.txt
# * 2021-01-15 13:37:42,610  --> /nfs/ruche-sixs/sixs-soleil/com-sixs/2021/Shutdown0/test/MacroCOStochio.txt ---
# * 2021-01-15 13:38:56,076 ----- KeyboardInterrupt -----
# * 2021-01-15 13:38:56,076  --> Number of ERROR : 0
# * 2021-01-15 13:38:56,076  --> END (MacroCOStochio.txt)
# * no data
#
# Fri, 15 Jan 2021 13:41:17
# * do.run("MacroCOStochio.txt")
# * log: log_MacroCOStochio.txt_20210115_13h41.txt
# * 2021-01-15 13:41:17,967  --> /nfs/ruche-sixs/sixs-soleil/com-sixs/2021/Shutdown0/test/MacroCOStochio.txt ---
# * 2021-01-15 13:44:40,300 ----- KeyboardInterrupt -----
# * 2021-01-15 13:44:40,301  --> Number of ERROR : 0
# * 2021-01-15 13:44:40,301  --> END (MacroCOStochio.txt)
# * no data
#
# Fri, 15 Jan 2021 13:50:03
# * do.run("MacroCOStochio.txt")
# * log: log_MacroCOStochio.txt_20210115_13h50.txt
# * 2021-01-15 13:50:03,333  --> /nfs/ruche-sixs/sixs-soleil/com-sixs/2021/Shutdown0/test/MacroCOStochio.txt ---
# * No end
# * **data : testbatchstochio.txt**
#
# ### xcat.log stops here
#
# log: log_MacroCOStochio_Kflow.txt_20210115_14h56.txt
# * 2021-01-15 14:56:12,393  --> /nfs/ruche-sixs/sixs-soleil/com-sixs/2021/Shutdown0/test/MacroCOStochio_Kflow.txt ---
# * 2021-01-15 14:59:15,094 ----- KeyboardInterrupt -----
# * 2021-01-15 14:59:15,095  --> Number of ERROR : 1
# * 2021-01-15 14:59:15,095  --> END (MacroCOStochio_Kflow.txt)
# * data : testbatchstochiobis.txt ? bad data, copy of testbatchstochio.txt
#
# log: log_MacroCOStochio_Kflow.txt_20210115_15h02.txt
# * 2021-01-15 15:02:24,649  --> /nfs/ruche-sixs/sixs-soleil/com-sixs/2021/Shutdown0/test/MacroCOStochio_Kflow.txt ---
# * 2021-01-15 15:49:44,885  --> END (MacroCOStochio_Kflow.txt)
#
#
#
#
# # Unknown data
# * highly probable that it is MacroCOStocjio_Kflow2.txt
# * **data : testbatchstochio_tris.txt (15:57)**

# %% [markdown]
# # RGA channels
#
#
# Channel |  Mass(amu)|     Name|                 Cal Factor|  Noise Floor| CEM Status
# ------------ | ------------- | ------------- | ------------- | ------------- | -------------
#  1         | 28.00          | CO                    | 1.00         | 7            | OFF
#  2         | 32.00          | O2                    | 1.00         | 7            | OFF
#  3         | 40.00          | Ar                    | 1.00         | 7            | OFF
#  4         | 44.00          | CO2                   | 1.00         | 7            | OFF
#  5         | 12.00          | C                     | 1.00         | 7            | OFF
#  6         | 2.00           | H2                    | 1.00         | 7            | OFF

# %% [markdown]
# # Macros
# * Macro_LowCO.txt, last edit : friday, 10h27
# * MacroBatch.txt, last edit : friday, 11h16
# * MacroCOStochio.txt, last edit : friday, 13h44
# * MacroCOStochio_Kflow.txt, last edit : friday, 15h02
# * MacroCOStochio_Kflow2.txt, last edit : saturday, 11h49, but probably right after the previous file

# %% [markdown]
# ## Import modules

# %%
# %run -i xcat_scripts/RGAsrs.py 

# %run -i xcat_scripts/xcat04.py

# %% [markdown]
# ### 14/01

# %%
# %%bash
# cd xcat_data/14-01
# ls *.txt
# Out:
# 20210112-151135.txt
# 20210114-174718.txt
# 20210114_test.txt

# %%
# xcat_data/14-01/20210114_test.txt

data, sttime, dictGas = RgaLoad("xcat_data/14-01/20210114_test.txt") # rga dataset

NormRga = RgaNormPtotPlot("xcat_data/14-01/20210114_test.txt", [28, 32, 40, 44], 0.5, TimeRange = [sttime, 4500], plot = "YES")

# %% [markdown]
# ### 15/01

# %%
# %%bash
# cd xcat_data/15-01
# ls *.txt
# Out:
# Test01.txt
# Testbatchfinal.txt
# testbatchstochio_bis.txt
# testbatchstochio_tris.txt
# testbatchstochio.txt

# %%
# "xcat_data/15-01/Test01.txt"

data, sttime, dictGas = RgaLoad("xcat_data/15-01/Test01.txt") # rga dataset

NormRga = RgaNormPtotPlot("xcat_data/15-01/Test01.txt", [28, 32, 40, 44], 0.5, TimeRange = [sttime, 4500], plot = "YES")

# %%
# "xcat_data/15-01/Test01.txt"

data, sttime, dictGas = RgaLoad("xcat_data/15-01/Test01.txt") # rga dataset

NormRga = RgaPlot("xcat_data/15-01/Test01.txt", [28, 32, 40, 44])
# Out:
# No Time window

# %%
# "xcat_data/15-01/Testbatchfinal.txt"

data, sttime, dictGas = RgaLoad("xcat_data/15-01/Testbatchfinal.txt") # rga dataset

NormRga = RgaNormPtotPlot("xcat_data/15-01/Testbatchfinal.txt", [28, 32, 40, 44], 0.5, TimeRange = [sttime, 4500], plot = "YES")

# %%
# "xcat_data/15-01/Testbatchfinal.txt"

data, sttime, dictGas = RgaLoad("xcat_data/15-01/Testbatchfinal.txt") # rga dataset

NormRga = RgaPlot("xcat_data/15-01/Testbatchfinal.txt", [28, 32, 40, 44])
# Out:
# No Time window

# %%
# "xcat_data/15-01/testbatchstochio.txt"

data, sttime, dictGas = RgaLoad("xcat_data/15-01/testbatchstochio.txt") # rga dataset

NormRga = RgaNormPtotPlot("xcat_data/15-01/testbatchstochio.txt", [28, 32, 40, 44], 0.5, TimeRange = [sttime, 4500], plot = "YES")

# %%
# "xcat_data/15-01/testbatchstochio.txt"

data, sttime, dictGas = RgaLoad("xcat_data/15-01/testbatchstochio.txt") # rga dataset

NormRga = RgaPlot("xcat_data/15-01/testbatchstochio.txt", [28, 32, 40, 44])
# Out:
# No Time window

# %%
# "xcat_data/15-01/testbatchstochio_bis.txt"

# data, sttime, dictGas = RgaLoad("xcat_data/15-01/testbatchstochio_bis.txt") # rga dataset

# NormRga = RgaNormPtotPlot("xcat_data/15-01/testbatchstochio_bis.txt", [28, 32, 40, 44], 0.5, TimeRange = [sttime, 4500], plot = "YES")

# %%
# "xcat_data/15-01/testbatchstochio_tris.txt"

data, sttime, dictGas = RgaLoad("xcat_data/15-01/testbatchstochio_tris.txt") # rga dataset

NormRga = RgaNormPtotPlot("xcat_data/15-01/testbatchstochio_tris.txt", [28, 32, 40, 44], 0.5, TimeRange = [sttime, 3200], plot = "YES")

# %% [markdown]
# # Conclusions
#
# * We manage to see CO2 in 15-01/testbatchstochio.txt and 15-01/testbatchstochiotris.txt
# * sadly no data for the macro : MacroCOStochio_Kflow.txt
# * best conditions : high flux seems to limit noise on CO2 (see MacroCOStochio_Kflow2.txt macro), keeping stoechiometry seems to also help the procduction of CO2 (see scriptscondstochioxB; x ∈ [1, 2, 3, 4]). Batching increases production and noise (for short periods of time, see previous figure)
# * essayer sans échantillon

# %% [markdown]
# ![Kflow2](logbook/logbook_Kflow2.jpeg)

# %% [markdown]
# ![kflow](logbook/logbook_Kflow.jpeg)

# %%
plt.plot([14, 28, 56, 112], [2.5, 3.4, 4.6, 6.3])

# %% [markdown]
# ![title](logbook/logbook_stochio_python.jpeg)

# %% [markdown]
# ## Use modules to load valve positions

# %%
# %run -i xcat_scripts/RGAsrs.py 

# %run -i xcat_scripts/xcat04.py

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/Documents/PhD_local/PhDScripts/xcat/xcat_scripts/xcat04.py in <module>
# ----> 1 XCAT.rga_df_interpolated.copy()
#
# AttributeError: type object 'XCAT' has no attribute 'rga_df_interpolated'

# %%
vectAll = RgaSelect("xcat_data/15-01/testbatchstochio_tris.txt", [28, 32, 40, 44], [sttime, 3200])

# %%
vectAll[:,0]
# Out:
# array([0.00000000e+00, 1.01399994e+00, 2.04299998e+00, ...,
#        3.19717800e+03, 3.19822300e+03, 3.19919000e+03])

# %%
RgaPlot("xcat_data/15-01/testbatchstochio_tris.txt", [28, 32, 40, 44], TimeRange = [sttime, 3200])
# Out:
# Time Window

# %%
np.where(col_ar[:-1] != col_ar[1:])[0]

# %% [markdown]
# # Data analysis for XCAT

# %%
# %run -i xcat_scripts/gaz_analysis.py

# %% [markdown]
# ## Import valves data, long file that is not separated for each experiment

# %%
XCAT_data = XCAT("xcat_data/14-01/20210114-174718.txt")
# Out:
#         time_no  flow_no  setpoint_no  valve_no       time_h2  flow_h2  \
# 0  1.610643e+09      0.0          0.0       0.0  1.610643e+09      0.0
# 1  1.610643e+09      0.0          0.0       0.0  1.610643e+09      0.0
# 2  1.610643e+09      0.0          0.0       0.0  1.610643e+09      0.0
# 3  1.610643e+09      0.0          0.0       0.0  1.610643e+09      0.0
# 4  1.610643e+09      0.0          0.0       0.0  1.610643e+09      0.0
#
#    setpoint_h2  valve_h2       time_o2  flow_o2  ...  flow_reactor  \
# 0          0.0       0.0  1.610643e+09      0.0  ...      0.499969
# 1          0.0       0.0  1.610643e+09      0.0  ...      0.499969
# 2          0.0       0.0  1.610643e+09      0.0  ...      0.499969
# 3          0.0       0.0  1.610643e+09      0.0  ...      0.499969
# 4          0.0       0.0  1.610643e+09      0.0  ...      0.500062
#
#    setpoint_reactor  valve_reactor    time_drain  flow_drain  setpoint_drain  \
# ...

# %% [markdown]
# ## Find the timestamp of the rga data, so that we know which part of the valves data we are interested in

# %%
XCAT_data.load_rga("xcat_data/15-01/testbatchstochio_tris.txt", rename_columns = True)
# Out:
# Timestamp: 1610722655.0 (unix epoch).
# Experiment duration: 3231 seconds.
# New interpolated dataframe created for rga.
#    time            CO            O2        Ar           CO2             C  \
# 0     0  7.814100e-07  2.950500e-07  0.000014  4.842800e-08  1.563300e-08
# 1     1  7.006254e-07  2.687062e-07  0.000014  4.839411e-08  1.150634e-08
# 2     2  6.379162e-07  2.382694e-07  0.000014  4.996848e-08  1.567111e-08
# 3     3  5.736156e-07  2.147715e-07  0.000014  4.710324e-08  1.053943e-08
# 4     4  5.135860e-07  1.904495e-07  0.000014  4.699428e-08  1.142081e-08
#
#              H2
# 0  3.238100e-08
# 1  2.663328e-08
# 2  3.236605e-08
# 3  2.824600e-08
# 4  3.208838e-08
#       time            CO            O2        Ar           CO2             C  \
# 3227  3227  3.184574e-08  7.585657e-09  0.000015  3.619005e-08  1.833385e-09
# 3228  3228  3.291178e-08  9.359771e-09  0.000015  3.657481e-08  1.347075e-09
# ...

# %% [markdown]
# ## Separate the xcat data in dataframes

# %%
XCAT_data.separate_xcat_dataframes(['O2','CO','Ar','shunt', "reactor", "drain", "valve"])

# Example of Ar
display(XCAT_data.o2_df.head())
display(XCAT_data.o2_df.tail())
# Out:
# New dataframe created starting for O2.
# New dataframe created starting for CO.
# New dataframe created starting for Ar.
# New dataframe created starting for shunt.
# New dataframe created starting for reactor.
# New dataframe created starting for drain.
# New dataframe created starting for valve.
#         time_o2  flow_o2  setpoint_o2  valve_o2
# 0  1.610643e+09      0.0          0.0       0.0
# 1  1.610643e+09      0.0          0.0       0.0
# 2  1.610643e+09      0.0          0.0       0.0
# 3  1.610643e+09      0.0          0.0       0.0
# 4  1.610643e+09      0.0          0.0       0.0
#              time_o2    flow_o2  setpoint_o2  valve_o2
# 102668  1.610726e+09  59.990625         60.0  4.312479
# 102669  1.610726e+09  59.998125         60.0  4.312502
# 102670  1.610726e+09  59.988750         60.0  4.312719
# 102671  1.610726e+09  60.005625         60.0  4.312490
# 102672  1.610726e+09  60.000000         60.0  4.312576

# %% [markdown]
# ## Truncate the xcat dataframes based on the timestamp of the rga data file

# %%
XCAT_data.truncate_xcat_df()

# Example of Ar
display(XCAT_data.ar_df_truncated.head())
display(XCAT_data.ar_df_truncated.tail())
# Out:
# New truncated dataframe created starting from timestamp for o2 and for 3231 seconds.
# New truncated dataframe created starting from timestamp for co and for 3231 seconds.
# New truncated dataframe created starting from timestamp for ar and for 3231 seconds.
# New truncated dataframe created starting from timestamp for shunt and for 3231 seconds.
# New truncated dataframe created starting from timestamp for reactor and for 3231 seconds.
# New truncated dataframe created starting from timestamp for drain and for 3231 seconds.
# New truncated dataframe created starting from timestamp for valve and for 3231 seconds.
#     time_ar    flow_ar  setpoint_ar  valve_ar
# 0  0.000000  50.109375         50.0  3.443594
# 1  0.814047  50.093750         50.0  3.442056
# 2  1.626093  50.054687         50.0  3.441640
# 3  2.437140  50.031250         50.0  3.441289
# 4  3.248186  50.023437         50.0  3.441042
#           time_ar    flow_ar  setpoint_ar  valve_ar
# ...

# %% [markdown]
# ## Interpolate on integer seconds

# %%
XCAT_data.interpolate_xcat_df()

# Example of Ar
display(XCAT_data.ar_df_interpolated.head())
display(XCAT_data.ar_df_interpolated.tail())
# Out:
# New interpolated dataframe created for o2.
# New interpolated dataframe created for co.
# New interpolated dataframe created for ar.
# New interpolated dataframe created for shunt.
# New interpolated dataframe created for reactor.
# New interpolated dataframe created for drain.
# New interpolated dataframe created for valve.
#    time_ar    flow_ar  setpoint_ar  valve_ar
# 0        0  50.109375         50.0  3.443594
# 1        1  50.085008         50.0  3.441915
# 2        2  50.041814         50.0  3.441460
# 3        3  50.022790         50.0  3.441187
# 4        4  50.038495         50.0  3.440119
#       time_ar    flow_ar  setpoint_ar  valve_ar
# 3227     3227  49.990986         50.0  3.452857
# 3228     3228  49.995083         50.0  3.452926
# 3229     3229  50.006959         50.0  3.452894
# 3230     3230  50.000471         50.0  3.452972
# 3231     3231  50.000029         50.0  3.453025

# %% [markdown]
# # Start plotting

# %%
XCAT_data.plot_rga_norm_ptot(plotted_columns = ["CO", "O2", "Ar", "CO2"],
                cursor_positions = [300, 840, 1140, 1680, 1980, 2220, 2520, 2760])

# %% [markdown]
# ## Plot rga dataset

# %%
# raw data

XCAT_data.plot_rga(
                plotted_columns = ["CO", "O2", "Ar", "CO2"],
                cursor_positions = [300, 840, 1140, 1680, 1980, 2220, 2520, 2760]                  )

# %%
# "xcat_data/15-01/testbatchstochio_tris.txt"

data, sttime, dictGas = RgaLoad("xcat_data/15-01/testbatchstochio_tris.txt") # rga dataset

NormRga = RgaNormPtotPlot("xcat_data/15-01/testbatchstochio_tris.txt", [28, 32, 40, 44], 0.5, TimeRange = [sttime, 3200], plot = "YES")

# %%
XCAT_data.plot_rga_norm_leak(
                        plotted_columns = ["CO", "O2", "Ar", "CO2"],
                        leak_values = [3.4, 1, 4.6, 1, 6.3, 1, 10],
                        leak_positions = [300, 840, 1140, 1680, 1980, 2220, 2520, 2760],
                        cursor_positions = [300, 840, 1140, 1680, 1980, 2220, 2520, 2760])

# %%
XCAT_data.plot_rga_norm_leak(
                        plotted_columns = ["CO", "O2", "Ar", "CO2"],
                        leak_values = [1, 1, 2, 1, 4, 1, 8],
                        leak_positions = [300, 840, 1140, 1680, 1980, 2220, 2520, 2760],
                        cursor_positions = [300, 840, 1140, 1680, 1980, 2220, 2520, 2760])

# %% [markdown]
# ## Ar

# %%
XCAT_data.plot_xcat_entry(["Ar"],
                          zoom1 = [0, None, 0, 60],
                          zoom2 = [0, None, None, None],
                          cursor_positions = [240, 960, 1080, 1800, 1920, 2340, 2460, 2880]
                         )

# %% [markdown]
# ## CO

# %%
XCAT_data.plot_xcat_entry(["CO"], zoom1 = [0, 2500, 0, 60])

# %% [markdown]
# ## O2

# %%
XCAT_data.plot_xcat_entry(["O2"], zoom1 = [0, 2500, 0, 60])

# %% [markdown]
# ## Valves

# %%
XCAT_data.plot_xcat_valves()
