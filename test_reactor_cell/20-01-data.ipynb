# %% [markdown]
# # Datasets

# %%
# %%bash
# cd xcat_data/20-01
# ls *.txt
# Out:
# 20210120-103821.txt
# 20210120-143002.txt
# longbatchstochio.txt
# tempramp2.txt
# tempramp.txt

# %%
# "xcat_data/15-01/Test01.txt"

data, sttime, dictGas = RgaLoad("xcat_data/20-01/longbatchstochio.txt") # rga dataset

NormRga = RgaNormPtotPlot("xcat_data/20-01/longbatchstochio.txt", [28, 32, 40, 44], 0.5, TimeRange = [sttime+1900, 4500], plot = "YES")

# %%
# "xcat_data/15-01/Test01.txt"

data, sttime, dictGas = RgaLoad("xcat_data/20-01/longbatchstochio.txt") # rga dataset

NormRga = RgaPlot("xcat_data/20-01/longbatchstochio.txt", [28, 32, 40, 44], TimeRange = [sttime+1900, 4500])
# Out:
# Time Window

# %%
# "xcat_data/15-01/Test01.txt"

data, sttime, dictGas = RgaLoad("xcat_data/20-01/tempramp.txt") # rga dataset

NormRga = RgaNormPtotPlot("xcat_data/20-01/tempramp.txt", [28, 17, 18, 30, 32, 44], 0.5, TimeRange = [sttime, 4000], plot = "YES")

# %%
# "xcat_data/15-01/Test01.txt"

data, sttime, dictGas = RgaLoad("xcat_data/20-01/tempramp.txt") # rga dataset

NormRga = RgaPlot("xcat_data/20-01/tempramp.txt", [28, 32, 40, 44], TimeRange = [sttime, 4000])
# Out:
# Time Window

# %%
# "xcat_data/15-01/Test01.txt"

data, sttime, dictGas = RgaLoad("xcat_data/20-01/tempramp2.txt") # rga dataset

NormRga = RgaNormPtotPlot("xcat_data/20-01/tempramp2.txt", [28, 17, 18, 30, 32, 44], 0.5, TimeRange = [sttime, 4000], plot = "YES")

# %%
# "xcat_data/15-01/Test01.txt"

data, sttime, dictGas = RgaLoad("xcat_data/20-01/tempramp2.txt") # rga dataset

NormRga = RgaPlot("xcat_data/20-01/tempramp2.txt", [28, 32, 40, 44], TimeRange = [sttime, 4000])
# Out:
# Time Window

# %% [markdown]
# # Homemade scripts

# %%
# %run -i xcat_scripts/gaz_analysis.py

# %% [markdown]
# # Long batch stochio
#
# Last dataset focusing on the production of CO

# %%
XCAT_data_0 = XCAT("xcat_data/20-01/20210120-143002.txt")
# Out:
#         time_no  flow_no  setpoint_no  valve_no       time_h2  flow_h2  \
# 0  1.611149e+09     32.0         32.0  3.395273  1.611149e+09  7.80750
# 1  1.611149e+09      0.0          0.0  0.000000  1.611149e+09  7.80750
# 2  1.611149e+09      0.0          0.0  0.000000  1.611149e+09  7.81125
# 3  1.611149e+09      0.0          0.0  0.000000  1.611149e+09  7.80750
# 4  1.611149e+09      0.0          0.0  0.000000  1.611149e+09  7.80750
#
#    setpoint_h2  valve_h2       time_o2   flow_o2  ...  flow_reactor  \
# 0     7.809375  4.105944  1.611149e+09  7.996875  ...      0.300000
# 1     7.809375  4.105967  1.611149e+09  7.995000  ...      0.300000
# 2     7.809375  4.105934  1.611149e+09  8.000625  ...      0.299906
# 3     7.809375  4.106019  1.611149e+09  7.996875  ...      0.300000
# 4     7.809375  4.106082  1.611149e+09  7.998750  ...      0.300000
#
#    setpoint_reactor  valve_reactor    time_drain  flow_drain  setpoint_drain  \
# 0               0.3       3.873886  1.611149e+09    0.498281        0.499969
# 1               0.3       3.873794  1.611149e+09    0.498375        0.499969
# 2               0.3       3.872162  1.611149e+09    0.498469        0.499969
# 3               0.3       3.871780  1.611149e+09    0.498469        0.499969
# 4               0.3       3.872633  1.611149e+09    0.498469        0.499969
#
#    valve_drain    time_valve  valve_MRS  valve_MIX
# 0     0.000000  1.611149e+09        6.0        5.0
# 1     0.000000  1.611149e+09        6.0        5.0
# 2     0.000000  1.611149e+09        6.0        5.0
# 3     0.000000  1.611149e+09        6.0        5.0
# 4     0.000045  1.611149e+09        6.0        5.0
#
# [5 rows x 35 columns]
#             time_no  flow_no  setpoint_no  valve_no       time_h2  flow_h2  \
# 10663  1.611158e+09      0.0          0.0       0.0  1.611158e+09      0.0
# 10664  1.611158e+09      0.0          0.0       0.0  1.611158e+09      0.0
# 10665  1.611158e+09      0.0          0.0       0.0  1.611158e+09      0.0
# 10666  1.611158e+09      0.0          0.0       0.0  1.611158e+09      0.0
# 10667  1.611158e+09      0.0          0.0       0.0  1.611158e+09      0.0
#
#        setpoint_h2  valve_h2       time_o2  flow_o2  ...  flow_reactor  \
# 10663          0.0       0.0  1.611158e+09      0.0  ...      0.499969
# 10664          0.0       0.0  1.611158e+09      0.0  ...      0.499969
# 10665          0.0       0.0  1.611158e+09      0.0  ...      0.499969
# 10666          0.0       0.0  1.611158e+09      0.0  ...      0.499969
# 10667          0.0       0.0  1.611158e+09      0.0  ...      0.499969
#
#        setpoint_reactor  valve_reactor    time_drain  flow_drain  \
# 10663          0.499969       3.812354  1.611158e+09    0.385781
# 10664          0.499969       3.811651  1.611158e+09    0.385875
# 10665          0.499969       3.810113  1.611158e+09    0.385875
# 10666          0.499969       3.810147  1.611158e+09    0.385875
# 10667          0.499969       3.810318  1.611158e+09    0.385969
#
#        setpoint_drain  valve_drain    time_valve  valve_MRS  valve_MIX
# 10663        0.499969          0.0  1.611158e+09        3.0        5.0
# 10664        0.499969          0.0  1.611158e+09        3.0        5.0
# 10665        0.499969          0.0  1.611158e+09        3.0        5.0
# 10666        0.499969          0.0  1.611158e+09        3.0        5.0
# 10667        0.499969          0.0  1.611158e+09        3.0        5.0
#
# [5 rows x 35 columns]

# %%
XCAT_data_0.load_rga(
    "xcat_data/20-01/longbatchstochio.txt",
    names = ["time", "CO", "CO2", "O2", "Ar", "H2", "H2O"],
    skiprows = 28)
# Out:
# Timestamp: 1611136186.0 (unix epoch).
# Experiment duration: 6605 seconds.
# New interpolated dataframe created for rga.
#    time            CO           CO2            O2            Ar            H2  \
# 0     0  7.073200e-08  9.456600e-08  4.520300e-09  7.156000e-09  1.649200e-07
# 1     1  7.023924e-08  9.478213e-08  4.663630e-09  7.100571e-09  1.645270e-07
# 2     2  6.972806e-08  9.490800e-08  4.796821e-09  7.050086e-09  1.641029e-07
# 3     3  6.895619e-08  9.375640e-08  4.786533e-09  7.069569e-09  1.632381e-07
# 4     4  6.823284e-08  9.266057e-08  4.770471e-09  7.095308e-09  1.623924e-07
#
#         H2O
# 0  0.000001
# 1  0.000001
# 2  0.000001
# 3  0.000001
# 4  0.000001
#       time            CO           CO2            O2        Ar            H2  \
# 6601  6601  1.800819e-08  2.063084e-08  2.732246e-09  0.000008  3.321092e-08
# 6602  6602  1.834232e-08  2.080431e-08  2.697449e-09  0.000008  3.323868e-08
# 6603  6603  1.869898e-08  2.099658e-08  2.649357e-09  0.000008  3.326804e-08
# 6604  6604  1.869998e-08  2.079435e-08  2.598619e-09  0.000008  3.341817e-08
# 6605  6605  1.866103e-08  2.054780e-08  2.547584e-09  0.000008  3.358188e-08
#
#                H2O
# 6601  1.271334e-07
# 6602  1.272177e-07
# 6603  1.273106e-07
# 6604  1.274840e-07
# 6605  1.276665e-07

# %%
XCAT_data_0.plot_rga_norm_ptot(
    ptot = 0.5,
    plotted_columns = ['CO', 'CO2', "O2", "Ar"],
    # cursor_positions = [300, 840, 1140, 1680, 1980, 2220, 2520, 2760],
    zoom = [2000, 6000, None, None]
)
# Out:
#    time        CO       CO2        O2        Ar        H2       H2O
# 0   0.0  0.023857  0.031896  0.001525  0.002414  0.055626  0.384682
# 1   1.0  0.023759  0.032061  0.001578  0.002402  0.055653  0.384547
# 2   2.0  0.023656  0.032198  0.001627  0.002392  0.055673  0.384453
# 3   3.0  0.023483  0.031929  0.001630  0.002408  0.055592  0.384958
# 4   4.0  0.023323  0.031672  0.001631  0.002425  0.055508  0.385442
# No cursor

# %%
XCAT_data_0.plot_rga(
    plotted_columns = ['CO', 'CO2', "O2", "Ar"],
    # cursor_positions = [300, 840, 1140, 1680, 1980, 2220, 2520, 2760],
    zoom = [2000, 6000, None, None]
)
# Out:
# No cursor

# %% [markdown]
# # Try to plot as a fct of temp

# %% [markdown]
# 128 secondes de retard pour les fichiers de sixs4, donc pour le log-macro ...
#
#
#
# <p>
#     log commence 34 secondes plut tôt pour tempramp2<br>
#     log commence 271 secondes plus tard pour tempramp
# </p>

# %% [markdown]
# # Temp ramp to 1.8 A

# %%
XCAT_data_1 = XCAT("xcat_data/20-01/20210120-143002.txt")
# Out:
#         time_no  flow_no  setpoint_no  valve_no       time_h2  flow_h2  \
# 0  1.611149e+09     32.0         32.0  3.395273  1.611149e+09  7.80750
# 1  1.611149e+09      0.0          0.0  0.000000  1.611149e+09  7.80750
# 2  1.611149e+09      0.0          0.0  0.000000  1.611149e+09  7.81125
# 3  1.611149e+09      0.0          0.0  0.000000  1.611149e+09  7.80750
# 4  1.611149e+09      0.0          0.0  0.000000  1.611149e+09  7.80750
#
#    setpoint_h2  valve_h2       time_o2   flow_o2  ...  flow_reactor  \
# 0     7.809375  4.105944  1.611149e+09  7.996875  ...      0.300000
# 1     7.809375  4.105967  1.611149e+09  7.995000  ...      0.300000
# 2     7.809375  4.105934  1.611149e+09  8.000625  ...      0.299906
# 3     7.809375  4.106019  1.611149e+09  7.996875  ...      0.300000
# 4     7.809375  4.106082  1.611149e+09  7.998750  ...      0.300000
#
#    setpoint_reactor  valve_reactor    time_drain  flow_drain  setpoint_drain  \
# 0               0.3       3.873886  1.611149e+09    0.498281        0.499969
# 1               0.3       3.873794  1.611149e+09    0.498375        0.499969
# 2               0.3       3.872162  1.611149e+09    0.498469        0.499969
# 3               0.3       3.871780  1.611149e+09    0.498469        0.499969
# 4               0.3       3.872633  1.611149e+09    0.498469        0.499969
#
#    valve_drain    time_valve  valve_MRS  valve_MIX
# 0     0.000000  1.611149e+09        6.0        5.0
# 1     0.000000  1.611149e+09        6.0        5.0
# 2     0.000000  1.611149e+09        6.0        5.0
# 3     0.000000  1.611149e+09        6.0        5.0
# 4     0.000045  1.611149e+09        6.0        5.0
#
# [5 rows x 35 columns]
#             time_no  flow_no  setpoint_no  valve_no       time_h2  flow_h2  \
# 10663  1.611158e+09      0.0          0.0       0.0  1.611158e+09      0.0
# 10664  1.611158e+09      0.0          0.0       0.0  1.611158e+09      0.0
# 10665  1.611158e+09      0.0          0.0       0.0  1.611158e+09      0.0
# 10666  1.611158e+09      0.0          0.0       0.0  1.611158e+09      0.0
# 10667  1.611158e+09      0.0          0.0       0.0  1.611158e+09      0.0
#
#        setpoint_h2  valve_h2       time_o2  flow_o2  ...  flow_reactor  \
# 10663          0.0       0.0  1.611158e+09      0.0  ...      0.499969
# 10664          0.0       0.0  1.611158e+09      0.0  ...      0.499969
# 10665          0.0       0.0  1.611158e+09      0.0  ...      0.499969
# 10666          0.0       0.0  1.611158e+09      0.0  ...      0.499969
# 10667          0.0       0.0  1.611158e+09      0.0  ...      0.499969
#
#        setpoint_reactor  valve_reactor    time_drain  flow_drain  \
# 10663          0.499969       3.812354  1.611158e+09    0.385781
# 10664          0.499969       3.811651  1.611158e+09    0.385875
# 10665          0.499969       3.810113  1.611158e+09    0.385875
# 10666          0.499969       3.810147  1.611158e+09    0.385875
# 10667          0.499969       3.810318  1.611158e+09    0.385969
#
#        setpoint_drain  valve_drain    time_valve  valve_MRS  valve_MIX
# 10663        0.499969          0.0  1.611158e+09        3.0        5.0
# 10664        0.499969          0.0  1.611158e+09        3.0        5.0
# 10665        0.499969          0.0  1.611158e+09        3.0        5.0
# 10666        0.499969          0.0  1.611158e+09        3.0        5.0
# 10667        0.499969          0.0  1.611158e+09        3.0        5.0
#
# [5 rows x 35 columns]

# %%
XCAT_data_1.load_rga(
    "xcat_data/20-01/tempramp2.txt",
    names = ["time", "N2", "NH", "NO", "N2O", "H2O", "H2", "Ar", "NH3", "O2", "C"],
    skiprows = 32)
# Out:
# Timestamp: 1611155073.0 (unix epoch).
# Experiment duration: 2731 seconds.
# New interpolated dataframe created for rga.
#    time            N2            NH            NO           N2O           H2O  \
# 0     0  2.812000e-08 -3.037700e-10  1.836700e-08  1.563300e-08  5.141500e-08
# 1     1  2.670900e-08 -3.037700e-10  2.112900e-08  1.563300e-08  5.141500e-08
# 2     2  2.670900e-08 -3.037700e-10  2.112900e-08  1.563300e-08  5.141500e-08
# 3     3  2.670900e-08 -3.037700e-10  2.112900e-08  1.563300e-08  5.073085e-08
# 4     4  2.670900e-08 -3.037700e-10  2.112900e-08  1.576569e-08  4.992200e-08
#
#              H2        Ar           NH3            O2             C
# 0  4.693900e-08  0.000019  2.670900e-08  2.112900e-08 -3.037700e-10
# 1  4.992200e-08  0.000019  2.252099e-08  2.390568e-08 -3.037700e-10
# 2  4.992200e-08  0.000019  2.601391e-08  2.274498e-08 -3.037700e-10
# 3  4.787826e-08  0.000019  2.670900e-08  2.443631e-08 -3.037700e-10
# 4  4.574991e-08  0.000019  2.670900e-08  2.643711e-08 -1.795093e-10
#       time            N2            NH            NO           N2O  \
# 2727  2727  2.762233e-08  9.763500e-10  2.112900e-08  1.821225e-08
# 2728  2728  2.670900e-08  9.763500e-10  2.112900e-08  1.925574e-08
# 2729  2729  2.670900e-08  9.763500e-10  2.112900e-08  1.809821e-08
# 2730  2730  2.715443e-08  9.763500e-10  2.112900e-08  1.978354e-08
# 2731  2731  2.812000e-08  5.864899e-10  2.112900e-08  1.899742e-08
#
#                H2O            H2        Ar           NH3            O2  \
# 2727  7.556190e-08  4.939506e-08  0.000018  6.178042e-08  2.130602e-07
# 2728  7.453400e-08  4.791625e-08  0.000018  5.944601e-08  1.979946e-07
# 2729  7.352685e-08  4.599512e-08  0.000018  5.594000e-08  1.831842e-07
# 2730  7.187794e-08  4.538758e-08  0.000018  5.404022e-08  1.664004e-07
# 2731  7.295300e-08  4.685043e-08  0.000018  4.992200e-08  1.523736e-07
#
#                  C
# 2727  3.205409e-09
# 2728  4.907600e-09
# 2729  4.067341e-09
# 2730  2.277900e-09
# 2731  2.677439e-09

# %%
XCAT_data_1.plot_rga_norm_ptot(
    ptot = 0.3,
    plotted_columns = ['NO', 'N2', "H2O", "N2O"],
    #cursor_positions = [300, 840, 1140, 1680, 1980, 2220, 2520, 2760],
    zoom = [200, 2690, None, None]
)
# Out:
#    time        N2        NH        NO       N2O       H2O        H2        Ar  \
# 0   0.0  0.000449 -0.000005  0.000293  0.000250  0.000821  0.000749  0.296685
# 1   1.0  0.000422 -0.000005  0.000334  0.000247  0.000813  0.000790  0.296669
# 2   2.0  0.000423 -0.000005  0.000335  0.000248  0.000814  0.000790  0.296628
# 3   3.0  0.000424 -0.000005  0.000335  0.000248  0.000805  0.000760  0.296626
# 4   4.0  0.000425 -0.000005  0.000336  0.000251  0.000794  0.000727  0.296630
#
#         NH3        O2         C
# 0  0.000426  0.000337 -0.000005
# 1  0.000356  0.000378 -0.000005
# 2  0.000412  0.000360 -0.000005
# 3  0.000424  0.000388 -0.000005
# 4  0.000425  0.000420 -0.000003
# No cursor

# %%
XCAT_data_1.plot_rga_norm_temp(
    amp_final = 1.8,
    nb_points = 100,
    #delta_time = 10,
    start_heating = 300 + 128 - 34,
    plotted_columns = ['NO', 'N2', "H2O", "N2O"],
)
# Out:
# Results saved in self.rga_during_heating DataFrame
# No cursor

# %%
# binned data

XCAT_data_1.plot_rga_norm_temp(
    amp_final = 1.8,
    nb_points = 100,
    delta_time = 10,
    start_heating = 300 + 128 - 34 + 180,
    plotted_columns = ['NO', 'N2', "H2O", "N2O"],
    binning = True,
    bins_nb = 200
)
# Out:
# Results saved in self.rga_during_heating DataFrame
# No cursor

# %%
XCAT_data_1.fit_error_function(
                   initial_guess = [30, 450, 20, 0],
                   new_amper_vect = np.linspace(0, 2, 200),
                   fitted_columns = ['NO', 'N2', "H2O", "N2O"],
                    binning = True)
# Out:
# No cursor

# %% [markdown]
# # Temp ramp to 1.5 A

# %%
XCAT_data_2 = XCAT("xcat_data/20-01/20210120-143002.txt")
# Out:
#         time_no  flow_no  setpoint_no  valve_no       time_h2  flow_h2  \
# 0  1.611149e+09     32.0         32.0  3.395273  1.611149e+09  7.80750
# 1  1.611149e+09      0.0          0.0  0.000000  1.611149e+09  7.80750
# 2  1.611149e+09      0.0          0.0  0.000000  1.611149e+09  7.81125
# 3  1.611149e+09      0.0          0.0  0.000000  1.611149e+09  7.80750
# 4  1.611149e+09      0.0          0.0  0.000000  1.611149e+09  7.80750
#
#    setpoint_h2  valve_h2       time_o2   flow_o2  ...  flow_reactor  \
# 0     7.809375  4.105944  1.611149e+09  7.996875  ...      0.300000
# 1     7.809375  4.105967  1.611149e+09  7.995000  ...      0.300000
# 2     7.809375  4.105934  1.611149e+09  8.000625  ...      0.299906
# 3     7.809375  4.106019  1.611149e+09  7.996875  ...      0.300000
# 4     7.809375  4.106082  1.611149e+09  7.998750  ...      0.300000
#
#    setpoint_reactor  valve_reactor    time_drain  flow_drain  setpoint_drain  \
# 0               0.3       3.873886  1.611149e+09    0.498281        0.499969
# 1               0.3       3.873794  1.611149e+09    0.498375        0.499969
# 2               0.3       3.872162  1.611149e+09    0.498469        0.499969
# 3               0.3       3.871780  1.611149e+09    0.498469        0.499969
# 4               0.3       3.872633  1.611149e+09    0.498469        0.499969
#
#    valve_drain    time_valve  valve_MRS  valve_MIX
# 0     0.000000  1.611149e+09        6.0        5.0
# 1     0.000000  1.611149e+09        6.0        5.0
# 2     0.000000  1.611149e+09        6.0        5.0
# 3     0.000000  1.611149e+09        6.0        5.0
# 4     0.000045  1.611149e+09        6.0        5.0
#
# [5 rows x 35 columns]
#             time_no  flow_no  setpoint_no  valve_no       time_h2  flow_h2  \
# 10663  1.611158e+09      0.0          0.0       0.0  1.611158e+09      0.0
# 10664  1.611158e+09      0.0          0.0       0.0  1.611158e+09      0.0
# 10665  1.611158e+09      0.0          0.0       0.0  1.611158e+09      0.0
# 10666  1.611158e+09      0.0          0.0       0.0  1.611158e+09      0.0
# 10667  1.611158e+09      0.0          0.0       0.0  1.611158e+09      0.0
#
#        setpoint_h2  valve_h2       time_o2  flow_o2  ...  flow_reactor  \
# 10663          0.0       0.0  1.611158e+09      0.0  ...      0.499969
# 10664          0.0       0.0  1.611158e+09      0.0  ...      0.499969
# 10665          0.0       0.0  1.611158e+09      0.0  ...      0.499969
# 10666          0.0       0.0  1.611158e+09      0.0  ...      0.499969
# 10667          0.0       0.0  1.611158e+09      0.0  ...      0.499969
#
#        setpoint_reactor  valve_reactor    time_drain  flow_drain  \
# 10663          0.499969       3.812354  1.611158e+09    0.385781
# 10664          0.499969       3.811651  1.611158e+09    0.385875
# 10665          0.499969       3.810113  1.611158e+09    0.385875
# 10666          0.499969       3.810147  1.611158e+09    0.385875
# 10667          0.499969       3.810318  1.611158e+09    0.385969
#
#        setpoint_drain  valve_drain    time_valve  valve_MRS  valve_MIX
# 10663        0.499969          0.0  1.611158e+09        3.0        5.0
# 10664        0.499969          0.0  1.611158e+09        3.0        5.0
# 10665        0.499969          0.0  1.611158e+09        3.0        5.0
# 10666        0.499969          0.0  1.611158e+09        3.0        5.0
# 10667        0.499969          0.0  1.611158e+09        3.0        5.0
#
# [5 rows x 35 columns]

# %%
XCAT_data_2.load_rga(
    "xcat_data/20-01/tempramp.txt",
    names = ["time", "N2", "NH", "NO", "N2O", "H2O", "H2", "Ar", "NH3", "O2", "C"],
    skiprows = 32)
# Out:
# Timestamp: 1611149317.0 (unix epoch).
# Experiment duration: 4072 seconds.
# New interpolated dataframe created for rga.
#    time            N2            NH            NO           N2O           H2O  \
# 0     0  1.633100e-07  4.907600e-09  2.251400e-08  2.670900e-08  1.072800e-07
# 1     1  1.640787e-07  4.907600e-09  2.267435e-08  2.812000e-08  1.089800e-07
# 2     2  1.605144e-07  4.907600e-09  2.600715e-08  2.811569e-08  1.089800e-07
# 3     3  1.586700e-07  4.934025e-09  2.670900e-08  2.673728e-08  1.089800e-07
# 4     4  1.586700e-07  6.171534e-09  2.669440e-08  2.812000e-08  1.089448e-07
#
#              H2        Ar           NH3        O2             C
# 0  4.398500e-08  0.000014  1.279800e-07  0.000001  1.156900e-08
# 1  4.418908e-08  0.000014  1.280608e-07  0.000002  7.926142e-09
# 2  4.842800e-08  0.000014  1.297346e-07  0.000002  1.560429e-08
# 3  4.836856e-08  0.000014  1.279800e-07  0.000002  6.414713e-09
# 4  4.549263e-08  0.000014  1.280165e-07  0.000002  1.561886e-08
#       time            N2            NH            NO           N2O  \
# 4068  4068  2.670900e-08 -1.262744e-10  2.132104e-08  2.053295e-08
# 4069  4069  2.670900e-08  7.595258e-10  2.112900e-08  1.871761e-08
# 4070  4070  2.670900e-08  9.763500e-10  2.112900e-08  2.064240e-08
# 4071  4071  2.785561e-08  9.763500e-10  2.112900e-08  2.112900e-08
# 4072  4072  2.695614e-08 -7.955346e-11  2.112900e-08  2.112900e-08
#
#                H2O            H2        Ar           NH3            O2  \
# 4068  8.273793e-08  4.781195e-08  0.000018  4.714546e-08  8.827647e-08
# 4069  8.385545e-08  4.412538e-08  0.000018  4.571217e-08  8.200467e-08
# 4070  8.612677e-08  4.143888e-08  0.000018  4.546200e-08  7.696571e-08
# 4071  8.655400e-08  4.463567e-08  0.000018  4.546200e-08  7.227017e-08
# 4072  8.189939e-08  4.546200e-08  0.000018  4.424370e-08  6.815685e-08
#
#                  C
# 4068  9.763500e-10
# 4069  9.763500e-10
# 4070  2.048598e-09
# 4071  2.277900e-09
# 4072  1.204320e-09

# %%
XCAT_data_2.plot_rga_norm_ptot(
    ptot = 0.3,
    plotted_columns = ['NO', 'N2', "H2O", "N2O"],
    #cursor_positions = [300, 840, 1140, 1680, 1980, 2220, 2520, 2760],
    zoom = [None, 4000, None, None]
)
# Out:
#    time        N2        NH        NO       N2O       H2O        H2        Ar  \
# 0   0.0  0.003134  0.000094  0.000432  0.000513  0.002059  0.000844  0.261501
# 1   1.0  0.003130  0.000094  0.000433  0.000536  0.002079  0.000843  0.261355
# 2   2.0  0.003061  0.000094  0.000496  0.000536  0.002078  0.000924  0.261263
# 3   3.0  0.003030  0.000094  0.000510  0.000511  0.002081  0.000924  0.261577
# 4   4.0  0.003027  0.000118  0.000509  0.000536  0.002078  0.000868  0.261335
#
#         NH3        O2         C
# 0  0.002456  0.028746  0.000222
# 1  0.002443  0.028936  0.000151
# 2  0.002474  0.028777  0.000298
# 3  0.002444  0.028709  0.000122
# 4  0.002442  0.028789  0.000298
# No cursor

# %%
XCAT_data_2.plot_rga_norm_temp(
    amp_final = 1.5,
    nb_points = 150,
    delta_time = 10,
    start_heating = 300 + 128 + 271,
    plotted_columns = ['NO', 'N2', "H2O", "N2O"],
)
# Out:
# Results saved in self.rga_during_heating DataFrame
# No cursor

# %%
# binned data
# if you add 3 minuts, the hysteresis fits
XCAT_data_2.plot_rga_norm_temp(
    amp_final = 1.5,
    nb_points = 150,
    delta_time = 10,
    start_heating = 300 + 128 + 271 + 180,
    plotted_columns = ['NO', 'N2', "H2O", "N2O"],
    binning = True,
    bins_nb = 300
)
# Out:
# Results saved in self.rga_during_heating DataFrame
# No cursor
